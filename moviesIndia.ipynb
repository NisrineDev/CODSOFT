# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('IMDbMoviesIndia.csv', encoding='latin1')

# %%
data
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                             #Homecoming  (2021)   90 min   Drama, Musical
# 3                                 #Yaaram  (2019)  110 min  Comedy, Romance
# 4                       ...And Once Again  (2010)  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN           Action
# 15505                               Zulmi  (1999)  129 min    Action, Drama
# 15506                           Zulmi Raj  (2005)      NaN           Action
# 15507                       Zulmi Shikari  (1988)      NaN           Action
# 15508                        Zulm-O-Sitam  (1998)  130 min    Action, Drama
#
# ...

# %%
data.dtypes
# Out:
# Name         object
# Year         object
# Duration     object
# Genre        object
# Rating      float64
# Votes        object
# Director     object
# Actor 1      object
# Actor 2      object
# Actor 3      object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB

# %%
data.describe()
# Out:
#             Rating
# count  7919.000000
# mean      5.841621
# std       1.381777
# min       1.100000
# 25%       4.900000
# 50%       6.000000
# 75%       6.800000
# max      10.000000

# %%
data.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# ...

# %%
data.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
data['Director'].value_counts()
# Out:
# Director
# Jayant Desai        58
# Kanti Shah          57
# Babubhai Mistry     50
# Mahesh Bhatt        48
# Master Bhagwan      47
#                     ..
# Naeem Siddiqui       1
# Shadaab Khan         1
# Mystelle Brabbee     1
# Kunal Shivdasani     1
# Kiran Thej           1
# Name: count, Length: 5938, dtype: int64

# %%
data['Director']
# Out:
# 0             J.S. Randhawa
# 1             Gaurav Bakshi
# 2        Soumyajit Majumdar
# 3                Ovais Khan
# 4              Amol Palekar
#                 ...
# 15504         Mahendra Shah
# 15505            Kuku Kohli
# 15506            Kiran Thej
# 15507                   NaN
# 15508          K.C. Bokadia
# Name: Director, Length: 15509, dtype: object

# %%
data['Duration'] = data['Duration'].str.replace('min','').astype(float)

# %%
data
# Out:
#                                      Name    Year  Duration            Genre  \
# 0                                             NaN       NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)     109.0            Drama
# 2                             #Homecoming  (2021)      90.0   Drama, Musical
# 3                                 #Yaaram  (2019)     110.0  Comedy, Romance
# 4                       ...And Once Again  (2010)     105.0            Drama
# ...                                   ...     ...       ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)       NaN           Action
# 15505                               Zulmi  (1999)     129.0    Action, Drama
# 15506                           Zulmi Raj  (2005)       NaN           Action
# 15507                       Zulmi Shikari  (1988)       NaN           Action
# 15508                        Zulm-O-Sitam  (1998)     130.0    Action, Drama
#
# ...

# %%
data.describe()
# Out:
#           Duration       Rating
# count  7240.000000  7919.000000
# mean    128.126519     5.841621
# std      28.912724     1.381777
# min       2.000000     1.100000
# 25%     110.000000     4.900000
# 50%     131.000000     6.000000
# 75%     147.000000     6.800000
# max     321.000000    10.000000

# %%
data['Votes'] = data['Votes'].str.replace(',','').str.replace('$','').str.replace('.','').str.replace('M','').astype(float)

# %%
data.describe()
# Out:
#           Duration       Rating          Votes
# count  7240.000000  7919.000000    7920.000000
# mean    128.126519     5.841621    1938.340783
# std      28.912724     1.381777   11601.694372
# min       2.000000     1.100000       5.000000
# 25%     110.000000     4.900000      16.000000
# 50%     131.000000     6.000000      55.000000
# 75%     147.000000     6.800000     404.000000
# max     321.000000    10.000000  591417.000000

# %%
from sklearn.preprocessing import MultiLabelBinarizer, LabelEncoder
genre = data['Genre']
genre = [g.split(', ') if isinstance (g,str) else [] for g in genre]
encoder = MultiLabelBinarizer()
encoder1 = LabelEncoder()
data['Director'] = encoder1.fit_transform(data['Director'])
data['Actor 1'] = encoder1.fit_transform(data['Actor 1'])
data['Actor 2'] = encoder1.fit_transform(data['Actor 2'])
data['Actor 3'] = encoder1.fit_transform(data['Actor 3'])
data['Genre'] = encoder1.fit_transform(data['Genre'])
#encoded_genre = encoder.fit_transform(genre)
#genre_names = encoder.classes_
#encoded_data = pd.DataFrame(encoded_genre, columns=genre_names) 
#encoded_data

# %%
data
# Out:
#                                      Name    Year  Duration  Genre  Rating  \
# 0                                             NaN       NaN    299     NaN
# 1      #Gadhvi (He thought he was Gandhi)  (2019)     109.0    299     7.0
# 2                             #Homecoming  (2021)      90.0    351     NaN
# 3                                 #Yaaram  (2019)     110.0    228     4.4
# 4                       ...And Once Again  (2010)     105.0    299     NaN
# ...                                   ...     ...       ...    ...     ...
# 15504                 Zulm Ko Jala Doonga  (1988)       NaN      0     4.6
# 15505                               Zulmi  (1999)     129.0     40     4.5
# 15506                           Zulmi Raj  (2005)       NaN      0     NaN
# 15507                       Zulmi Shikari  (1988)       NaN      0     NaN
# 15508                        Zulm-O-Sitam  (1998)     130.0     40     6.2
#
#        Votes  Director  Actor 1  Actor 2  Actor 3
# ...

# %%
movie_data = pd.concat([data.reset_index(drop=True)], axis=1)

# %%
movie_data
# Out:
#                                      Name    Year  Duration  Genre  Rating  \
# 0                                             NaN       NaN    299     NaN
# 1      #Gadhvi (He thought he was Gandhi)  (2019)     109.0    299     7.0
# 2                             #Homecoming  (2021)      90.0    351     NaN
# 3                                 #Yaaram  (2019)     110.0    228     4.4
# 4                       ...And Once Again  (2010)     105.0    299     NaN
# ...                                   ...     ...       ...    ...     ...
# 15504                 Zulm Ko Jala Doonga  (1988)       NaN      0     4.6
# 15505                               Zulmi  (1999)     129.0     40     4.5
# 15506                           Zulmi Raj  (2005)       NaN      0     NaN
# 15507                       Zulmi Shikari  (1988)       NaN      0     NaN
# 15508                        Zulm-O-Sitam  (1998)     130.0     40     6.2
#
#        Votes  Director  Actor 1  Actor 2  Actor 3
# ...

# %%
columns = ['Name']
movie_data.drop(columns, axis=1, inplace=True)

# %%
movie_data
# Out:
#          Year  Duration  Genre  Rating  Votes  Director  Actor 1  Actor 2  \
# 0         NaN       NaN    299     NaN    NaN      1926     2250      800
# 1      (2019)     109.0    299     7.0    8.0      1548     3280     4790
# 2      (2021)      90.0    351     NaN    NaN      5123     3713     2866
# 3      (2019)     110.0    228     4.4   35.0      3319     2917     1504
# 4      (2010)     105.0    299     NaN    NaN       385     3112     3462
# ...       ...       ...    ...     ...    ...       ...      ...      ...
# 15504  (1988)       NaN      0     4.6   11.0      2690     2586     4299
# 15505  (1999)     129.0     40     4.5  655.0      2499      227     4532
# 15506  (2005)       NaN      0     NaN    NaN      2424     3609     4891
# 15507  (1988)       NaN      0     NaN    NaN      5938     4718     4891
# 15508  (1998)     130.0     40     6.2   20.0      2195     1139     1589
#
#        Actor 3
# 0         3108
# 1          527
# 2         3450
# ...

# %%
movie_data.describe()
# Out:
#           Duration         Genre       Rating          Votes      Director  \
# count  7240.000000  15509.000000  7919.000000    7920.000000  15509.000000
# mean    128.126519    271.536205     5.841621    1938.340783   2987.815075
# std      28.912724    164.410098     1.381777   11601.694372   1717.609627
# min       2.000000      0.000000     1.100000       5.000000      0.000000
# 25%     110.000000    163.000000     4.900000      16.000000   1531.000000
# 50%     131.000000    299.000000     6.000000      55.000000   2922.000000
# 75%     147.000000    409.000000     6.800000     404.000000   4416.000000
# max     321.000000    485.000000    10.000000  591417.000000   5938.000000
#
#             Actor 1       Actor 2       Actor 3
# count  15509.000000  15509.000000  15509.000000
# mean    2574.342833   2832.121671   2869.035915
# std     1456.514606   1542.495914   1555.151952
# min        0.000000      0.000000      0.000000
# 25%     1302.000000   1518.000000   1542.000000
# ...

# %%
movie_data.isnull().sum()
# Out:
# Year         528
# Duration    8269
# Genre          0
# Rating      7590
# Votes       7589
# Director       0
# Actor 1        0
# Actor 2        0
# Actor 3        0
# dtype: int64

# %%
movie_data['Year'] = movie_data['Year'].str.replace(r'\(|\)',' ', regex=True).astype(float)

# %%
movie_data.describe()
# Out:
#                Year     Duration         Genre       Rating          Votes  \
# count  14981.000000  7240.000000  15509.000000  7919.000000    7920.000000
# mean    1987.012215   128.126519    271.536205     5.841621    1938.340783
# std       25.416689    28.912724    164.410098     1.381777   11601.694372
# min     1913.000000     2.000000      0.000000     1.100000       5.000000
# 25%     1968.000000   110.000000    163.000000     4.900000      16.000000
# 50%     1991.000000   131.000000    299.000000     6.000000      55.000000
# 75%     2009.000000   147.000000    409.000000     6.800000     404.000000
# max     2022.000000   321.000000    485.000000    10.000000  591417.000000
#
#            Director       Actor 1       Actor 2       Actor 3
# count  15509.000000  15509.000000  15509.000000  15509.000000
# mean    2987.815075   2574.342833   2832.121671   2869.035915
# std     1717.609627   1456.514606   1542.495914   1555.151952
# ...

# %%
movie_data['Year'].median()
# Out:
# 1991.0

# %%
movie_data['Year'].fillna(movie_data['Year'].median(), inplace=True)

# %%
movie_data['Year']
# Out:
# 0        1991.0
# 1        2019.0
# 2        2021.0
# 3        2019.0
# 4        2010.0
#           ...
# 15504    1988.0
# 15505    1999.0
# 15506    2005.0
# 15507    1988.0
# 15508    1998.0
# Name: Year, Length: 15509, dtype: float64

# %%
movie_data['Duration'].fillna(movie_data['Duration'].median(), inplace=True)

# %%
movie_data['Rating'].fillna(movie_data['Rating'].median(), inplace=True)

# %%
movie_data['Votes'].fillna(movie_data['Votes'].median(), inplace=True)

# %%
movie_data['Director'].fillna(movie_data['Director'].median(), inplace=True)

# %%
movie_data['Actor 1'].fillna(movie_data['Actor 1'].median(), inplace=True)

# %%
movie_data['Actor 2'].fillna(movie_data['Actor 2'].median(), inplace=True)

# %%
movie_data['Actor 3'].fillna(movie_data['Actor 3'].median(), inplace=True)

# %%
movie_data['Genre'].fillna(movie_data['Genre'].median(), inplace=True)

# %%
movie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      15509 non-null  float64
#  1   Duration  15509 non-null  float64
#  2   Genre     15509 non-null  int32
#  3   Rating    15509 non-null  float64
#  4   Votes     15509 non-null  float64
#  5   Director  15509 non-null  int32
#  6   Actor 1   15509 non-null  int32
#  7   Actor 2   15509 non-null  int32
#  8   Actor 3   15509 non-null  int32
# dtypes: float64(4), int32(5)
# memory usage: 787.7 KB

# %%
sns.heatmap(movie_data.corr(), cmap='Blues')
# Out:
# <Axes: >

# %%
movie_data
# Out:
#          Year  Duration  Genre  Rating  Votes  Director  Actor 1  Actor 2  \
# 0      1991.0     131.0    299     6.0   55.0      1926     2250      800
# 1      2019.0     109.0    299     7.0    8.0      1548     3280     4790
# 2      2021.0      90.0    351     6.0   55.0      5123     3713     2866
# 3      2019.0     110.0    228     4.4   35.0      3319     2917     1504
# 4      2010.0     105.0    299     6.0   55.0       385     3112     3462
# ...       ...       ...    ...     ...    ...       ...      ...      ...
# 15504  1988.0     131.0      0     4.6   11.0      2690     2586     4299
# 15505  1999.0     129.0     40     4.5  655.0      2499      227     4532
# 15506  2005.0     131.0      0     6.0   55.0      2424     3609     4891
# 15507  1988.0     131.0      0     6.0   55.0      5938     4718     4891
# 15508  1998.0     130.0     40     6.2   20.0      2195     1139     1589
#
#        Actor 3
# 0         3108
# 1          527
# 2         3450
# ...

# %%
features = ['Genre','Duration','Director','Actor 1','Actor 2','Actor 3']
X = movie_data[features]
y = movie_data['Rating']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.4, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(n_estimators=100, random_state=42)
rfr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = rfr.predict(X_test)

# %%
y_pred
# Out:
# array([6.002, 6.063, 5.924, ..., 6.738, 5.628, 5.864])

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, mean_squared_error
print('Mean Squared Error:', mean_squared_error(y_test,y_pred))
# Out:
# Mean Squared Error: 0.9331238124219895

# %%
from sklearn.svm import SVR
svm = SVR(kernel='rbf')
svm.fit(X_train,y_train)
# Out:
# SVR()

# %%
predictions = svm.predict(X_test)

# %%
predictions
# Out:
# array([6.09842814, 6.05133811, 6.0991671 , ..., 6.07593656, 5.96119004,
#        5.96718999])

# %%
print('Mean Squared Error:', mean_squared_error(y_test,predictions))
# Out:
# Mean Squared Error: 0.9899212242760101

# %%
from sklearn.tree import DecisionTreeRegressor
dct = DecisionTreeRegressor(max_depth=5)
dct.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
predicted_y = dct.predict(X_test)

# %%
print('Mean Squared Error:', mean_squared_error(y_test,predicted_y))
# Out:
# Mean Squared Error: 0.9476214140919487

# %%
plt.hist(X_train, bins=10)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor, export_graphviz
import graphviz
regressor = DecisionTreeRegressor(max_depth=3)
regressor.fit(X, y)

# Export decision tree with specified feature names and executable path
dot_data = export_graphviz(
    regressor,
    out_file=None,
    feature_names=X.columns,  # Assuming you have named columns
    filled=True,
    rounded=True,
    special_characters=True
)

# Create the graph with explicitly specifying the Graphviz executable path
graph = graphviz.Source(dot_data, filename="decision_tree", format="png", engine='dot')

# Save or display the graph
graph.render(filename='regressor', format='png', cleanup=True)
# Out:
# 'regressor.png'

# %%
from sklearn.model_selection import learning_curve
def plot_learning_curve(model, X, y):
    train_sizes, train_scores, test_scores = learning_curve(model, X, y, train_sizes=np.linspace(0.1, 1.0, 5))
    train_mean = np.mean(train_scores, axis=1)
    train_std = np.std(train_scores, axis=1)
    test_mean = np.mean(test_scores, axis=1)
    test_std = np.std(test_scores, axis=1)
    plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Accuracy')
    plt.fill_between(train_sizes, train_mean + train_std,train_mean - train_std ,alpha=0.15,color='blue')
    plt.plot(train_sizes, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Validation Accuracy')
    plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
    plt.xlabel('Training Samples')
    plt.ylabel('Accuracy')
    plt.title('Learning Curve')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plot_learning_curve(regressor, X, y)
